# %% [markdown]
#                                      Install Dependencies

# %%
pip install ultralytics roboflow --quiet

# %% [markdown]
#                                         Download Dataset

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="E1x9SNxASqTWFzBNR1wy")
project = rf.workspace("shyams-workspace-i8nfl").project("triple-riding-bltnf-1i9mw")
version = project.version(1)
dataset = version.download("yolov8")

# %% [markdown]
#                                              Train Model

# %%
from ultralytics import YOLO
model = YOLO('yolov8n.pt')
model.train(
    data=f'{dataset.location}/data.yaml',
    epochs=100,
    imgsz=416,
    batch=32,
    name='triple_riding_detector',
    patience=20,
    workers=4,
    cache=True,
    device=0,
    optimizer='AdamW',
    )
print('Training complete!')

# %% [markdown]
#                                         Evaluate

# %%
metrics = model.val()
print(f'mAP50:     {metrics.box.map50:.3f}')
print(f'mAP50-95:  {metrics.box.map:.3f}')
print(f'Precision: {metrics.box.p.mean():.3f}')
print(f'Recall:    {metrics.box.r.mean():.3f}')

# %% [markdown]
#                             Download the best part

# %%
from google.colab import files
files.download('/content/runs/detect/traffic_light_detector/weights/best.pt')

# %% [markdown]
# {
#  "nbformat": 4,
#  "nbformat_minor": 5,
#  "metadata": {
#   "kernelspec": {
#    "display_name": "Python 3",
#    "language": "python",
#    "name": "python3"
#   },
#   "language_info": {
#    "name": "python",
#    "version": "3.12.0"
#   }
#  },
#  "cells": [
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "# Step 1 - Install dependencies\n",
#     "!pip install ultralytics roboflow --quiet"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "# Step 2 - Download dataset\n",
#     "from roboflow import Roboflow\n",
#     "rf = Roboflow(api_key='YOUR_API_KEY_HERE')\n",
#     "project = rf.workspace('YOUR_WORKSPACE').project('YOUR_PROJECT')\n",
#     "dataset = project.version(1).download('yolov8')"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "# Step 3 - Train model\n",
#     "from ultralytics import YOLO\n",
#     "model = YOLO('yolov8n.pt')\n",
#     "model.train(\n",
#     "    data=f'{dataset.location}/data.yaml',\n",
#     "    epochs=100,\n",
#     "    imgsz=416,\n",
#     "    batch=32,\n",
#     "    name='triple_riding_detector',\n",
#     "    patience=20,\n",
#     "    workers=4,\n",
#     "    cache=True,\n",
#     "    device=0,\n",
#     "    optimizer='AdamW',\n",
#     ")\n",
#     "print('Training complete!')"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "# Step 4 - Evaluate\n",
#     "metrics = model.val()\n",
#     "print(f'mAP50:     {metrics.box.map50:.3f}')\n",
#     "print(f'mAP50-95:  {metrics.box.map:.3f}')\n",
#     "print(f'Precision: {metrics.box.p.mean():.3f}')\n",
#     "print(f'Recall:    {metrics.box.r.mean():.3f}')"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "# Step 5 - Download best.pt\n",
#     "from google.colab import files\n",
#     "files.download('/content/runs/detect/triple_riding_detector/weights/best.pt')"
#    ]
#   }
#  ]
# }
